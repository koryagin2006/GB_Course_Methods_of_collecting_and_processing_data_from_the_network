# %% [markdown]
# # Задание
# Создать приложение, которое будет из готового файла с данными «Сбербанка» выводить результат по параметрам:
# - Тип данных
# - Интервал дат
#
# Область визуализировать выводимые данные с помощью графика

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.style

# %%
DATASET_PATH = 'opendata.csv'
df = pd.read_csv(DATASET_PATH, encoding='Windows-1251')
df['date'] = df['date'].astype('datetime64[ns]')

# %%
# df = df.set_index('date')

# %%
df.head(3)
# Out:
#                                                     name  region   value
# date
# 2013-01-15  Количество заявок на потребительские кредиты  Россия  571147
# 2013-02-15  Количество заявок на потребительские кредиты  Россия  504508
# 2013-03-15  Количество заявок на потребительские кредиты  Россия  628803

# %%
df['name'].value_counts()
# Out:
# Средняя сумма заявки на потребительский кредит    6132
# Количество заявок на потребительские кредиты      6132
# Средняя сумма заявки на ипотечный кредит          6131
# Количество заявок на ипотечные кредиты            6131
# В среднем депозитов в руб. на человека            5124
# В среднем руб. на текущем счете на человека       5124
# Средняя пенсия                                    5124
# Средние расходы по картам                         5124
# Количество новых депозитов                        4956
# Средняя сумма нового депозита                     4956
# Средняя зарплата                                  4116
# Средние траты в ресторане фастфуд                 3948
# Средние траты в ресторане                         3948
# Средний чек в формате Фастфуд                     3948
# Средний чек в формате Ресторан                    3948
# Name: name, dtype: int64

# %%
filter_date = (df['date'] > '2015-01-01') & (df['date'] < '2020-01-01')
filter_name = df['name'] == 'Количество заявок на потребительские кредиты'
filter_reg = df['region'] == 'Оренбургская область'

df_2 = df.loc[filter_date & filter_reg & filter_name]
df_2
# Out:
#                                               name                region  \
# 2725  Количество заявок на потребительские кредиты  Оренбургская область
# 2726  Количество заявок на потребительские кредиты  Оренбургская область
# 2727  Количество заявок на потребительские кредиты  Оренбургская область
# 2728  Количество заявок на потребительские кредиты  Оренбургская область
# 2729  Количество заявок на потребительские кредиты  Оренбургская область
# 2730  Количество заявок на потребительские кредиты  Оренбургская область
# 2731  Количество заявок на потребительские кредиты  Оренбургская область
# 2732  Количество заявок на потребительские кредиты  Оренбургская область
# 2733  Количество заявок на потребительские кредиты  Оренбургская область
# 2734  Количество заявок на потребительские кредиты  Оренбургская область
# 2735  Количество заявок на потребительские кредиты  Оренбургская область
# 2736  Количество заявок на потребительские кредиты  Оренбургская область
# 2737  Количество заявок на потребительские кредиты  Оренбургская область
# 2738  Количество заявок на потребительские кредиты  Оренбургская область
# 2739  Количество заявок на потребительские кредиты  Оренбургская область
# 2740  Количество заявок на потребительские кредиты  Оренбургская область
# 2741  Количество заявок на потребительские кредиты  Оренбургская область
# 2742  Количество заявок на потребительские кредиты  Оренбургская область
# 2743  Количество заявок на потребительские кредиты  Оренбургская область
# 2744  Количество заявок на потребительские кредиты  Оренбургская область
# 2745  Количество заявок на потребительские кредиты  Оренбургская область
# 2746  Количество заявок на потребительские кредиты  Оренбургская область
# 2747  Количество заявок на потребительские кредиты  Оренбургская область
# 2748  Количество заявок на потребительские кредиты  Оренбургская область
# 2749  Количество заявок на потребительские кредиты  Оренбургская область
